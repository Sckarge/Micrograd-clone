# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/sckarge/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.21 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: cycler>=0.10 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sckarge/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Let us try to get an understanding of derivatives first and what results they provide
def f(x):
    return 2*x**2 + 5

# %%
f(3.0)
# Out:
# 23.0

# %%
xs = np.arange(-100,100,1)
ys = f(xs)
plt.plot(xs,ys)

# %%
# We are going to simulate a derivative as the equation
# df/dx = (f(x+h) - f(x))/h
# with a very small value of h instead to show x -> 0

# %%
h = 0.00000000001
x = 3.0
dfdx = (f(x+h) - f(x))/h
dfdx
# Out:
# 0.0
